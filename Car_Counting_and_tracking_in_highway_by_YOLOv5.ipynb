# %%
import cv2
import torch
import numpy as np
from tracker import *

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in /Users/fady/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-3-23 Python-3.11.5 torch-2.2.1 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████████████████████████████████| 14.1M/14.1M [00:09<00:00, 1.56MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
cap=cv2.VideoCapture('highway.mp4')

# %%
tracker = Tracker()

# %%
def POINTS(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN :  
        colorsBGR = [x, y]
        print(colorsBGR)

# %%
cv2.namedWindow('FRAME')
cv2.setMouseCallback('FRAME', POINTS)
area = [(448,445),(428,472),(526,482),(524,449)]
area1 = [(710,429),(724,442),(775,434),(769,419)]

# %%
c = set()

# %%
C = set()

# %%
while True:
    ret,frame=cap.read()
    if not ret:
        break

    frame=cv2.resize(frame,(1020,600))
    cv2.polylines(frame,[np.array(area,np.int32)],True,(0,255,0),2)
    cv2.polylines(frame,[np.array(area1,np.int32)],True,(0,255,255),2)
    results=model(frame)
    points = []
    for index , row in results.pandas().xyxy[0].iterrows():
        x1 = int(row['xmin'])
        y1 = int(row['ymin'])
        x2 = int(row['xmax'])
        y2 = int(row['ymax'])
        n=(row['name'])
        if 'car' in n:
            points.append([x1,y1,x2,y2])
            #cv2.rectangle(frame,(x1,y1),(x2,y2),(255,0,255),2)
            #cv2.putText(frame,str(n),(x1,y1),cv2.FONT_HERSHEY_PLAIN,2,(255,0,0),2)
        
    boxes_id = tracker.update(points) 
    #print(boxes_id)
    for box_id in boxes_id:
        x , y , w , h , idd = box_id
        cv2.rectangle(frame,(x,y),(w,h),(255,0,255),2)
        cv2.putText(frame,str(idd),(x,y),cv2.FONT_HERSHEY_PLAIN,3,(255,0,0),2)
        cv2.circle(frame,(w,h),4,(0,255,0),-1)
        results = cv2.pointPolygonTest(np.array(area,np.int32),(w,h),False)
        results1 = cv2.pointPolygonTest(np.array(area1,np.int32),(w,h),False)
        #print(results)
        if results>= 0 :
            c.add(idd)
        if results1>= 0 :
            C.add(idd)    
    a = len(c)
    b = len(C)
    cv2.putText(frame,'number of cars in the green region is ='+str(a),(50,65),cv2.FONT_HERSHEY_PLAIN,2,(0,255,0),2)
    cv2.putText(frame,'number of cars in the yellow region is ='+str(b),(50,90),cv2.FONT_HERSHEY_PLAIN,2,(0,0,0),2)
    cv2.imshow("FRAME",frame)
    if cv2.waitKey(1)&0xFF==27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4e9c184 _ZN15MenuBarInstance14EnableAutoShowEv + 56
# 4   HIToolbox                           0x00000001b4e3f310 SetMenuBarObscured + 372
# 5   HIToolbox                           0x00000001b4e3eee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 6   HIToolbox                           0x00000001b4e38fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 7   HIToolbox                           0x00000001b4dffcd0 _NotifyEventLoopObservers + 176
# 8   HIToolbox                           0x00000001b4e3896c AcquireEventFromQueue + 432
# 9   HIToolbox                           0x00000001b4e27c84 ReceiveNextEventCommon + 320
# 10  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 11  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 12  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 13  cv2.abi3.so                         0x00000001629c71d8 cvWaitKey + 476
# 14  cv2.abi3.so                         0x00000001629c1328 _ZN2cv9waitKeyExEi + 168
# 15  cv2.abi3.so                         0x00000001629c1420 _ZN2cv7waitKeyEi + 48
# 16  cv2.abi3.so                         0x0000000161ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 17  python3.11                          0x0000000104e7a928 cfunction_call + 60
# 18  python3.11                          0x0000000104f5d8a4 _PyEval_EvalFrameDefault + 197284
# 19  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 20  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 21  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 22  python3.11                          0x0000000104f612f8 _PyEval_EvalFrameDefault + 212216
# 23  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 24  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 25  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 26  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 27  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 28  python3.11                          0x0000000104e3504c gen_send + 52
# 29  python3.11                          0x0000000104f61b30 _PyEval_EvalFrameDefault + 214320
# 30  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 31  python3.11                          0x0000000104e1daf0 method_vectorcall + 272
# 32  python3.11                          0x0000000104f625b0 _PyEval_EvalFrameDefault + 217008
# 33  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 34  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 35  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 36  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 37  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 38  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 39  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 40  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 41  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 42  _asyncio.cpython-311-darwin.so      0x0000000105b34370 task_step_impl + 440
# 43  _asyncio.cpython-311-darwin.so      0x0000000105b34128 task_step + 68
# 44  _asyncio.cpython-311-darwin.so      0x0000000105b34c30 task_wakeup + 136
# 45  python3.11                          0x0000000104e7b2f8 cfunction_vectorcall_O + 92
# 46  python3.11                          0x0000000104f85dc4 _PyObject_VectorcallTstate.4603 + 88
# 47  python3.11                          0x0000000104f85c88 context_run + 92
# 48  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 49  python3.11                          0x0000000104f6265c _PyEval_EvalFrameDefault + 217180
# 50  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 51  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 52  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 53  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 54  python3.11                          0x0000000104f5d6b0 _PyEval_EvalFrameDefault + 196784
# 55  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 56  python3.11                          0x0000000104fe67f8 pymain_run_module + 212
# 57  python3.11                          0x0000000104fe6290 Py_RunMain + 1292
# 58  python3.11                          0x0000000104daf99c main + 56
# 59  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4ea0380 _ZL19AutoShowHideHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 104
# 4   HIToolbox                           0x00000001b4e004c0 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 1092
# 5   HIToolbox                           0x00000001b4dff940 _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 356
# 6   HIToolbox                           0x00000001b4dff7d0 SendEventToEventTargetWithOptions + 44
# 7   HIToolbox                           0x00000001b4e3f9cc _ZL29ToolboxEventDispatcherHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 472
# 8   HIToolbox                           0x00000001b4e00968 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 2284
# 9   HIToolbox                           0x00000001b4dff940 _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 356
# 10  HIToolbox                           0x00000001b4e15bb8 SendEventToEventTarget + 40
# 11  AppKit                              0x00000001ae9ccf00 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 2044
# 12  cv2.abi3.so                         0x00000001629c71d8 cvWaitKey + 476
# 13  cv2.abi3.so                         0x00000001629c1328 _ZN2cv9waitKeyExEi + 168
# 14  cv2.abi3.so                         0x00000001629c1420 _ZN2cv7waitKeyEi + 48
# 15  cv2.abi3.so                         0x0000000161ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  python3.11                          0x0000000104e7a928 cfunction_call + 60
# 17  python3.11                          0x0000000104f5d8a4 _PyEval_EvalFrameDefault + 197284
# 18  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 19  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 20  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 21  python3.11                          0x0000000104f612f8 _PyEval_EvalFrameDefault + 212216
# 22  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 23  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 24  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 25  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 26  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 27  python3.11                          0x0000000104e3504c gen_send + 52
# 28  python3.11                          0x0000000104f61b30 _PyEval_EvalFrameDefault + 214320
# 29  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 30  python3.11                          0x0000000104e1daf0 method_vectorcall + 272
# 31  python3.11                          0x0000000104f625b0 _PyEval_EvalFrameDefault + 217008
# 32  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 33  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 34  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 35  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 36  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 37  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 38  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 39  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 40  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 41  _asyncio.cpython-311-darwin.so      0x0000000105b34370 task_step_impl + 440
# 42  _asyncio.cpython-311-darwin.so      0x0000000105b34128 task_step + 68
# 43  _asyncio.cpython-311-darwin.so      0x0000000105b34c30 task_wakeup + 136
# 44  python3.11                          0x0000000104e7b2f8 cfunction_vectorcall_O + 92
# 45  python3.11                          0x0000000104f85dc4 _PyObject_VectorcallTstate.4603 + 88
# 46  python3.11                          0x0000000104f85c88 context_run + 92
# 47  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 48  python3.11                          0x0000000104f6265c _PyEval_EvalFrameDefault + 217180
# 49  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 50  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 51  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 52  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 53  python3.11                          0x0000000104f5d6b0 _PyEval_EvalFrameDefault + 196784
# 54  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 55  python3.11                          0x0000000104fe67f8 pymain_run_module + 212
# 56  python3.11                          0x0000000104fe6290 Py_RunMain + 1292
# 57  python3.11                          0x0000000104daf99c main + 56
# 58  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4e9c5c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001b4e098c8 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1196
# 3   HIToolbox                           0x00000001b4e9c004 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 180
# 4   AppKit                              0x00000001aec8bd30 -[NSApplication _setPresentationOptions:instance:flags:] + 956
# 5   AppKit                              0x00000001aeb2193c -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 404
# 6   AppKit                              0x00000001af3e8960 -[_NSFullScreenSpace(PresentationInstance) activateFullScreenPresentationOptions] + 148
# 7   AppKit                              0x00000001af2756ac -[_NSEnterFullScreenTransitionController _doSucceededToEnterFullScreen] + 588
# 8   AppKit                              0x00000001af275fac __65-[_NSEnterFullScreenTransitionController _performEnterFullScreen]_block_invoke + 376
# 9   AppKit                              0x00000001aed12d8c __NSFullScreenDockConnectionSendEnterForSpace_block_invoke + 168
# 10  libxpc.dylib                        0x00000001ab3da42c _xpc_connection_reply_callout + 124
# 11  libxpc.dylib                        0x00000001ab3da31c _xpc_connection_call_reply_async + 88
# 12  libdispatch.dylib                   0x00000001ab4e2584 _dispatch_client_callout3 + 20
# 13  libdispatch.dylib                   0x00000001ab500710 _dispatch_mach_msg_async_reply_invoke + 344
# 14  libdispatch.dylib                   0x00000001ab4f0c70 _dispatch_main_queue_drain + 756
# 15  libdispatch.dylib                   0x00000001ab4f096c _dispatch_main_queue_callback_4CF + 44
# 16  CoreFoundation                      0x00000001ab78ad40 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 16
# 17  CoreFoundation                      0x00000001ab7487c0 __CFRunLoopRun + 2036
# 18  CoreFoundation                      0x00000001ab747878 CFRunLoopRunSpecific + 612
# 19  HIToolbox                           0x00000001b4e27fa0 RunCurrentEventLoopInMode + 292
# 20  HIToolbox                           0x00000001b4e27c30 ReceiveNextEventCommon + 236
# 21  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 22  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 23  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 24  cv2.abi3.so                         0x00000001629c71d8 cvWaitKey + 476
# 25  cv2.abi3.so                         0x00000001629c1328 _ZN2cv9waitKeyExEi + 168
# 26  cv2.abi3.so                         0x00000001629c1420 _ZN2cv7waitKeyEi + 48
# 27  cv2.abi3.so                         0x0000000161ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 28  python3.11                          0x0000000104e7a928 cfunction_call + 60
# 29  python3.11                          0x0000000104f5d8a4 _PyEval_EvalFrameDefault + 197284
# 30  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 31  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 32  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 33  python3.11                          0x0000000104f612f8 _PyEval_EvalFrameDefault + 212216
# 34  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 35  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 36  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 37  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 38  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 39  python3.11                          0x0000000104e3504c gen_send + 52
# 40  python3.11                          0x0000000104f61b30 _PyEval_EvalFrameDefault + 214320
# 41  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 42  python3.11                          0x0000000104e1daf0 method_vectorcall + 272
# 43  python3.11                          0x0000000104f625b0 _PyEval_EvalFrameDefault + 217008
# 44  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 45  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 46  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 47  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 48  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 49  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 50  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 51  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 52  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 53  _asyncio.cpython-311-darwin.so      0x0000000105b34370 task_step_impl + 440
# 54  _asyncio.cpython-311-darwin.so      0x0000000105b34128 task_step + 68
# 55  _asyncio.cpython-311-darwin.so      0x0000000105b34c30 task_wakeup + 136
# 56  python3.11                          0x0000000104e7b2f8 cfunction_vectorcall_O + 92
# 57  python3.11                          0x0000000104f85dc4 _PyObject_VectorcallTstate.4603 + 88
# 58  python3.11                          0x0000000104f85c88 context_run + 92
# 59  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 60  python3.11                          0x0000000104f6265c _PyEval_EvalFrameDefault + 217180
# 61  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 62  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 63  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 64  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 65  python3.11                          0x0000000104f5d6b0 _PyEval_EvalFrameDefault + 196784
# 66  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 67  python3.11                          0x0000000104fe67f8 pymain_run_module + 212
# 68  python3.11                          0x0000000104fe6290 Py_RunMain + 1292
# 69  python3.11                          0x0000000104daf99c main + 56
# 70  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4e0930c _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 72
# 4   HIToolbox                           0x00000001b4e9c8a0 _ZN15MenuBarInstance20AutoShowHideObserverEjP14OpaqueEventRefPv + 216
# 5   HIToolbox                           0x00000001b4dffcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001b4e33bb0 PostEventToQueueInternal + 696
# 7   HIToolbox                           0x00000001b4e35340 _ZL29CreateAndPostEventWithCGEventP9__CGEventjhP17__CFMachPortBoost + 460
# 8   HIToolbox                           0x00000001b4e34c44 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 296
# 9   HIToolbox                           0x00000001b4e34ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 10  CoreFoundation                      0x00000001ab779410 __CFMachPortPerform + 260
# 11  CoreFoundation                      0x00000001ab749f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 12  CoreFoundation                      0x00000001ab749eb8 __CFRunLoopDoSource1 + 520
# 13  CoreFoundation                      0x00000001ab7488a4 __CFRunLoopRun + 2264
# 14  CoreFoundation                      0x00000001ab747878 CFRunLoopRunSpecific + 612
# 15  HIToolbox                           0x00000001b4e27fa0 RunCurrentEventLoopInMode + 292
# 16  HIToolbox                           0x00000001b4e27c30 ReceiveNextEventCommon + 236
# 17  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 18  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 19  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 20  cv2.abi3.so                         0x00000001629c71d8 cvWaitKey + 476
# 21  cv2.abi3.so                         0x00000001629c1328 _ZN2cv9waitKeyExEi + 168
# 22  cv2.abi3.so                         0x00000001629c1420 _ZN2cv7waitKeyEi + 48
# 23  cv2.abi3.so                         0x0000000161ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 24  python3.11                          0x0000000104e7a928 cfunction_call + 60
# 25  python3.11                          0x0000000104f5d8a4 _PyEval_EvalFrameDefault + 197284
# 26  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 27  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 28  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 29  python3.11                          0x0000000104f612f8 _PyEval_EvalFrameDefault + 212216
# 30  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 31  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 32  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 33  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 34  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 35  python3.11                          0x0000000104e3504c gen_send + 52
# 36  python3.11                          0x0000000104f61b30 _PyEval_EvalFrameDefault + 214320
# 37  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 38  python3.11                          0x0000000104e1daf0 method_vectorcall + 272
# 39  python3.11                          0x0000000104f625b0 _PyEval_EvalFrameDefault + 217008
# 40  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 41  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 42  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 43  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 44  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 45  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 46  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 47  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 48  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 49  _asyncio.cpython-311-darwin.so      0x0000000105b34370 task_step_impl + 440
# 50  _asyncio.cpython-311-darwin.so      0x0000000105b34128 task_step + 68
# 51  _asyncio.cpython-311-darwin.so      0x0000000105b34c30 task_wakeup + 136
# 52  python3.11                          0x0000000104e7b2f8 cfunction_vectorcall_O + 92
# 53  python3.11                          0x0000000104f85dc4 _PyObject_VectorcallTstate.4603 + 88
# 54  python3.11                          0x0000000104f85c88 context_run + 92
# 55  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 56  python3.11                          0x0000000104f6265c _PyEval_EvalFrameDefault + 217180
# 57  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 58  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 59  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 60  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 61  python3.11                          0x0000000104f5d6b0 _PyEval_EvalFrameDefault + 196784
# 62  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 63  python3.11                          0x0000000104fe67f8 pymain_run_module + 212
# 64  python3.11                          0x0000000104fe6290 Py_RunMain + 1292
# 65  python3.11                          0x0000000104daf99c main + 56
# 66  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4e0930c _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 72
# 4   HIToolbox                           0x00000001b4e9c8a0 _ZN15MenuBarInstance20AutoShowHideObserverEjP14OpaqueEventRefPv + 216
# 5   HIToolbox                           0x00000001b4dffcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001b4e33bb0 PostEventToQueueInternal + 696
# 7   HIToolbox                           0x00000001b4e35340 _ZL29CreateAndPostEventWithCGEventP9__CGEventjhP17__CFMachPortBoost + 460
# 8   HIToolbox                           0x00000001b4e34c44 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 296
# 9   HIToolbox                           0x00000001b4e34ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 10  CoreFoundation                      0x00000001ab779410 __CFMachPortPerform + 260
# 11  CoreFoundation                      0x00000001ab749f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 12  CoreFoundation                      0x00000001ab749eb8 __CFRunLoopDoSource1 + 520
# 13  CoreFoundation                      0x00000001ab7488a4 __CFRunLoopRun + 2264
# 14  CoreFoundation                      0x00000001ab747878 CFRunLoopRunSpecific + 612
# 15  HIToolbox                           0x00000001b4e27fa0 RunCurrentEventLoopInMode + 292
# 16  HIToolbox                           0x00000001b4e27c30 ReceiveNextEventCommon + 236
# 17  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 18  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 19  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 20  cv2.abi3.so                         0x00000001629c71d8 cvWaitKey + 476
# 21  cv2.abi3.so                         0x00000001629c1328 _ZN2cv9waitKeyExEi + 168
# 22  cv2.abi3.so                         0x00000001629c1420 _ZN2cv7waitKeyEi + 48
# 23  cv2.abi3.so                         0x0000000161ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 24  python3.11                          0x0000000104e7a928 cfunction_call + 60
# 25  python3.11                          0x0000000104f5d8a4 _PyEval_EvalFrameDefault + 197284
# 26  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 27  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 28  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 29  python3.11                          0x0000000104f612f8 _PyEval_EvalFrameDefault + 212216
# 30  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 31  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 32  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 33  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 34  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 35  python3.11                          0x0000000104e3504c gen_send + 52
# 36  python3.11                          0x0000000104f61b30 _PyEval_EvalFrameDefault + 214320
# 37  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 38  python3.11                          0x0000000104e1daf0 method_vectorcall + 272
# 39  python3.11                          0x0000000104f625b0 _PyEval_EvalFrameDefault + 217008
# 40  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 41  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 42  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 43  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 44  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 45  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 46  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 47  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 48  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 49  _asyncio.cpython-311-darwin.so      0x0000000105b34370 task_step_impl + 440
# 50  _asyncio.cpython-311-darwin.so      0x0000000105b34128 task_step + 68
# 51  _asyncio.cpython-311-darwin.so      0x0000000105b34c30 task_wakeup + 136
# 52  python3.11                          0x0000000104e7b2f8 cfunction_vectorcall_O + 92
# 53  python3.11                          0x0000000104f85dc4 _PyObject_VectorcallTstate.4603 + 88
# 54  python3.11                          0x0000000104f85c88 context_run + 92
# 55  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 56  python3.11                          0x0000000104f6265c _PyEval_EvalFrameDefault + 217180
# 57  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 58  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 59  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 60  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 61  python3.11                          0x0000000104f5d6b0 _PyEval_EvalFrameDefault + 196784
# 62  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 63  python3.11                          0x0000000104fe67f8 pymain_run_module + 212
# 64  python3.11                          0x0000000104fe6290 Py_RunMain + 1292
# 65  python3.11                          0x0000000104daf99c main + 56
# 66  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4e2790c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x00000001b4e098c8 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1196
# 3   HIToolbox                           0x00000001b4e0930c _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 72
# 4   HIToolbox                           0x00000001b4e092b4 _ZL25UpdateAllAggregateUIModes21MenuBarAnimationStyleh + 120
# 5   HIToolbox                           0x00000001b4e09228 SetSystemUIMode + 140
# 6   AppKit                              0x00000001aec8bd40 -[NSApplication _setPresentationOptions:instance:flags:] + 972
# 7   AppKit                              0x00000001aeb21954 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 428
# 8   CoreFoundation                      0x00000001ab73e560 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 148
# 9   CoreFoundation                      0x00000001ab7dc044 ___CFXRegistrationPost_block_invoke + 88
# 10  CoreFoundation                      0x00000001ab7dbf8c _CFXRegistrationPost + 440
# 11  CoreFoundation                      0x00000001ab70fb64 _CFXNotificationPost + 708
# 12  Foundation                          0x00000001ac5ff38c -[NSNotificationCenter postNotificationName:object:userInfo:] + 88
# 13  AppKit                              0x00000001aec8c2b4 spacesNotificationHandler + 96
# 14  SkyLight                            0x00000001b0379214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 15  SkyLight                            0x00000001b0377e10 CGSSnarfAndDispatchDatagrams + 808
# 16  SkyLight                            0x00000001b069fa9c SLSGetNextEventRecordInternal + 344
# 17  SkyLight                            0x00000001b04a0fb0 SLEventCreateNextEvent + 16
# 18  HIToolbox                           0x00000001b4e34b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 19  HIToolbox                           0x00000001b4e34ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 20  CoreFoundation                      0x00000001ab779410 __CFMachPortPerform + 260
# 21  CoreFoundation                      0x00000001ab749f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 22  CoreFoundation                      0x00000001ab749eb8 __CFRunLoopDoSource1 + 520
# 23  CoreFoundation                      0x00000001ab7488a4 __CFRunLoopRun + 2264
# 24  CoreFoundation                      0x00000001ab747878 CFRunLoopRunSpecific + 612
# 25  HIToolbox                           0x00000001b4e27fa0 RunCurrentEventLoopInMode + 292
# 26  HIToolbox                           0x00000001b4e27c30 ReceiveNextEventCommon + 236
# 27  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 28  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 29  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 30  cv2.abi3.so                         0x00000001629c71d8 cvWaitKey + 476
# 31  cv2.abi3.so                         0x00000001629c1328 _ZN2cv9waitKeyExEi + 168
# 32  cv2.abi3.so                         0x00000001629c1420 _ZN2cv7waitKeyEi + 48
# 33  cv2.abi3.so                         0x0000000161ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 34  python3.11                          0x0000000104e7a928 cfunction_call + 60
# 35  python3.11                          0x0000000104f5d8a4 _PyEval_EvalFrameDefault + 197284
# 36  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 37  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 38  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 39  python3.11                          0x0000000104f612f8 _PyEval_EvalFrameDefault + 212216
# 40  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 41  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 42  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 43  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 44  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 45  python3.11                          0x0000000104e3504c gen_send + 52
# 46  python3.11                          0x0000000104f61b30 _PyEval_EvalFrameDefault + 214320
# 47  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 48  python3.11                          0x0000000104e1daf0 method_vectorcall + 272
# 49  python3.11                          0x0000000104f625b0 _PyEval_EvalFrameDefault + 217008
# 50  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 51  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 52  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 53  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 54  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 55  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 56  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 57  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 58  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 59  _asyncio.cpython-311-darwin.so      0x0000000105b34370 task_step_impl + 440
# 60  _asyncio.cpython-311-darwin.so      0x0000000105b34128 task_step + 68
# 61  _asyncio.cpython-311-darwin.so      0x0000000105b34c30 task_wakeup + 136
# 62  python3.11                          0x0000000104e7b2f8 cfunction_vectorcall_O + 92
# 63  python3.11                          0x0000000104f85dc4 _PyObject_VectorcallTstate.4603 + 88
# 64  python3.11                          0x0000000104f85c88 context_run + 92
# 65  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 66  python3.11                          0x0000000104f6265c _PyEval_EvalFrameDefault + 217180
# 67  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 68  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 69  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 70  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 71  python3.11                          0x0000000104f5d6b0 _PyEval_EvalFrameDefault + 196784
# 72  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 73  python3.11                          0x0000000104fe67f8 pymain_run_module + 212
# 74  python3.11                          0x0000000104fe6290 Py_RunMain + 1292
# 75  python3.11                          0x0000000104daf99c main + 56
# 76  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4e9c5c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001b4e3f27c SetMenuBarObscured + 224
# 3   HIToolbox                           0x00000001b4e3eee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 4   HIToolbox                           0x00000001b4e38fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 5   HIToolbox                           0x00000001b4dffcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001b4e3896c AcquireEventFromQueue + 432
# 7   HIToolbox                           0x00000001b4e27c84 ReceiveNextEventCommon + 320
# 8   HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 9   AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 10  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 11  cv2.abi3.so                         0x00000001629c71d8 cvWaitKey + 476
# 12  cv2.abi3.so                         0x00000001629c1328 _ZN2cv9waitKeyExEi + 168
# 13  cv2.abi3.so                         0x00000001629c1420 _ZN2cv7waitKeyEi + 48
# 14  cv2.abi3.so                         0x0000000161ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 15  python3.11                          0x0000000104e7a928 cfunction_call + 60
# 16  python3.11                          0x0000000104f5d8a4 _PyEval_EvalFrameDefault + 197284
# 17  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 18  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 19  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 20  python3.11                          0x0000000104f612f8 _PyEval_EvalFrameDefault + 212216
# 21  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 22  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 23  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 24  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 25  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 26  python3.11                          0x0000000104e3504c gen_send + 52
# 27  python3.11                          0x0000000104f61b30 _PyEval_EvalFrameDefault + 214320
# 28  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 29  python3.11                          0x0000000104e1daf0 method_vectorcall + 272
# 30  python3.11                          0x0000000104f625b0 _PyEval_EvalFrameDefault + 217008
# 31  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 32  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 33  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 34  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 35  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 36  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 37  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 38  python3.11                          0x0000000104f382e8 _PyEval_EvalFrameDefault + 44264
# 39  python3.11                          0x0000000104e348f4 gen_send_ex2 + 204
# 40  _asyncio.cpython-311-darwin.so      0x0000000105b34370 task_step_impl + 440
# 41  _asyncio.cpython-311-darwin.so      0x0000000105b34128 task_step + 68
# 42  _asyncio.cpython-311-darwin.so      0x0000000105b34c30 task_wakeup + 136
# 43  python3.11                          0x0000000104e7b2f8 cfunction_vectorcall_O + 92
# 44  python3.11                          0x0000000104f85dc4 _PyObject_VectorcallTstate.4603 + 88
# 45  python3.11                          0x0000000104f85c88 context_run + 92
# 46  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 47  python3.11                          0x0000000104f6265c _PyEval_EvalFrameDefault + 217180
# 48  python3.11                          0x0000000104f2ab88 _PyEval_Vector + 464
# 49  python3.11                          0x0000000104f2a928 PyEval_EvalCode + 248
# 50  python3.11                          0x0000000104f25b64 builtin_exec + 332
# 51  python3.11                          0x0000000104e7b5d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 52  python3.11                          0x0000000104f5d6b0 _PyEval_EvalFrameDefault + 196784
# 53  python3.11                          0x0000000104e17e28 _PyFunction_Vectorcall + 476
# 54  python3.11                          0x0000000104fe67f8 pymain_run_module + 212
# 55  python3.11                          0x0000000104fe6290 Py_RunMain + 1292
# 56  python3.11                          0x0000000104daf99c main + 56
# 57  dyld                                0x00000001ab33fe50 start + 2544
